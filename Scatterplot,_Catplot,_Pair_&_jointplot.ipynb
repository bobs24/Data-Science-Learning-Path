# %% [markdown]
# <a href="https://colab.research.google.com/github/bobs24/Data-Science-Learning-Path/blob/Learning/Scatterplot%2C_Catplot%2C_Pair_%26_jointplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('diamonds')

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"
 
#code here
sns.scatterplot(data=df,x='carat',y='price',size='depth',sizes=(1,10),hue='clarity',palette="ch:r=-.2,d=.3_r",linewidth=0.1)
#sns.color_palette("ch:r=-.2,d=.3_r",as_cmap=True)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
#code here
g = sns.catplot(x="clarity", 
                y="price",
                kind="box",
                col="cut",
                data=df,
                showfliers=False)
with sns.axes_style('white'):
  sns.set_style('ticks')

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=17mSiL-qQtFB2D8rUYB0v7d6tOrOHDoh6)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df = df.sample(n=300, random_state=123)
#code here
with sns.axes_style('darkgrid'):
  sns.pairplot(df, hue='cut',vars=['carat','depth','table','price'],markers = ['p', 'o', 's', 'D', 'X'],corner=True)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=12rStINwUNGpqZd1iIGaqzTIvw9irAkJ0)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
#code here
df = df.sample(n=300, random_state=123)
with sns.axes_style('white'):
  sns.jointplot(data=df, x="carat", y="price", kind="kde")

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=17MY9L4bUSxuCIRxDl7Ey34_RrfXjlcim)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1A5vQ66KLZ9sbJ_qDoAkuAF3Z213ricZW)

# %%
df = df.sample(n=300, random_state=123)
with sns.axes_style('darkgrid'):
  sns1=sns.jointplot("carat", "price", data=df, kind='reg',xlim=(0.25,2.25))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
