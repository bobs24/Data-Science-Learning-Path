# %% [markdown]
# <a href="https://colab.research.google.com/github/bobs24/Data-Science-Learning-Path/blob/Learning/Learning_Pandas_for_Data_Science_advance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DEFINE A PANDAS DATAFRAME

# %%
# Pandas is a data manipulation and analysis tool that is built on Numpy.
# Pandas uses a data structure known as DataFrame (think of it as Microsoft excel in Python). 
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows and columns).
import pandas as pd

# %%
# define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary
employee_df = pd.DataFrame({'Employee ID':[1, 2, 3, 4], 
                            'Employee Name':['Laila Aly', 'Kate Steve', 'Nicole Mitch', 'Francis Morris'], 
                            'Annual Salary [$]':[35000, 40000, 100000, 25000], 
                            'Years with Company':[5, 7, 10, 1]})
employee_df
# Out:
#    Employee ID   Employee Name  Annual Salary [$]  Years with Company
# 0            1       Laila Aly              35000                   5
# 1            2      Kate Steve              40000                   7
# 2            3    Nicole Mitch             100000                  10
# 3            4  Francis Morris              25000                   1

# %%
# obtain the data type 
type(employee_df)
# Out:
# pandas.core.frame.DataFrame

# %%
employee_df.head(2)
# Out:
#    Employee ID Employee Name  Annual Salary [$]  Years with Company
# 0            1     Laila Aly              35000                   5
# 1            2    Kate Steve              40000                   7

# %%
# you can only view the last couple of rows using .tail()
employee_df.tail(1)
# Out:
#    Employee ID   Employee Name  Annual Salary [$]  Years with Company
# 3            4  Francis Morris              25000                   1

# %%
# obtain the shape of the DataFrame (#rows, #columns)
employee_df.shape
# Out:
# (4, 4)

# %%
# Obtain DataFrame information 
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee ID         4 non-null      int64
#  1   Employee Name       4 non-null      object
#  2   Annual Salary [$]   4 non-null      int64
#  3   Years with Company  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# #READ CSV AND HTML DATA

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')

# %%
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# Read tabular data using read_html
house_prices_df = pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')

# %%
house_prices_df[0]
# Out:
#                                                 City  ...                                    12 Month Change
# 0                                      Vancouver, BC  ...                                           + 2.63 %
# 1                                       Toronto, Ont  ...                                            +10.2 %
# 2                                        Ottawa, Ont  ...                                           + 15.4 %
# 3                                       Calgary, Alb  ...                                            – 1.5 %
# 4                                      Montreal, Que  ...                                            + 9.3 %
# 5                                        Halifax, NS  ...                                            + 3.6 %
# 6                                       Regina, Sask  ...                                            – 3.9 %
# 7                                    Fredericton, NB  ...                                            – 4.3 %
# 8  (adsbygoogle = window.adsbygoogle || []).push(...  ...  (adsbygoogle = window.adsbygoogle || []).push(...
#
# [9 rows x 3 columns]

# %%
house_prices_df[1]
# Out:
#                                              Province  ...                                    12 Month Change
# 0                                    British Columbia  ...                                            + 7.6 %
# 1                                             Ontario  ...                                            – 3.2 %
# 2                                             Alberta  ...                                            – 7.5 %
# 3                                              Quebec  ...                                            + 7.6 %
# 4                                            Manitoba  ...                                            – 1.4 %
# 5                                        Saskatchewan  ...                                            – 3.8 %
# 6                                         Nova Scotia  ...                                            + 3.5 %
# 7                                Prince Edward Island  ...                                            + 3.0 %
# 8                             Newfoundland / Labrador  ...                                            – 1.6 %
# 9                                       New Brunswick  ...                                            – 2.2 %
# 10                                   Canadian Average  ...                                            – 1.3 %
# 11  (adsbygoogle = window.adsbygoogle || []).push(...  ...  (adsbygoogle = window.adsbygoogle || []).push(...
#
# [12 rows x 3 columns]

# %% [markdown]
# #WRITE DATAFRAME INTO CSV

# %%
employee_df = pd.DataFrame({'Employee ID':[1, 2, 3, 4], 
                            'Employee Name':['Laila Aly', 'Kate Steve', 'Nicole Mitch', 'Francis Morris'], 
                            'Annual Salary [$]':[35000, 40000, 100000, 25000], 
                            'Years with Company':[5, 7, 10, 1]})
employee_df
# Out:
#    Employee ID   Employee Name  Annual Salary [$]  Years with Company
# 0            1       Laila Aly              35000                   5
# 1            2      Kate Steve              40000                   7
# 2            3    Nicole Mitch             100000                  10
# 3            4  Francis Morris              25000                   1

# %%
# write to a csv file without an index
employee_df.to_csv('employee_info_with_index.csv', index = True)

# %% [markdown]
# #SETTING/RESETTING INDEX

# %%
# Pandas is used to read a csv file and store data in a DataFrame
# Note that a numeric index is being set by default
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# assign a specific column to be the index as follows
employee_df.set_index("First Name", inplace = True)
employee_df
# Out:
#            Last Name     Salary  ...  Postal Code                    Email
# First Name                       ...
# Mike             Moe    5000.00  ...      N94 3M0           bird@gmail.com
# Noah            Ryan   10000.00  ...      N8S 14K       nsmall@hotmail.com
# Nina          Keller    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Chanel         Steve   11072.02  ...      N7T 3E6         chanel@gmail.com
# Kate            Noor    5000.00  ...      K8N 5H6         kate@hotmail.com
# Samer             Mo  100000.00  ...      J7H 3HY          samer@gmail.com
# Heba          Ismail   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Laila            Aly   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Joseph        Patton    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Noah           Moran    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 5 columns]

# %%
# go back and use numeric index using reset_index
employee_df.reset_index(inplace = True)
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# set the index name when you read the csv file as follows
employee_df = pd.read_csv('employee_information.csv', index_col = 'First Name')
employee_df
# Out:
#            Last Name     Salary  ...  Postal Code                    Email
# First Name                       ...
# Mike             Moe    5000.00  ...      N94 3M0           bird@gmail.com
# Noah            Ryan   10000.00  ...      N8S 14K       nsmall@hotmail.com
# Nina          Keller    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Chanel         Steve   11072.02  ...      N7T 3E6         chanel@gmail.com
# Kate            Noor    5000.00  ...      K8N 5H6         kate@hotmail.com
# Samer             Mo  100000.00  ...      J7H 3HY          samer@gmail.com
# Heba          Ismail   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Laila            Aly   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Joseph        Patton    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Noah           Moran    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 5 columns]

# %% [markdown]
# #SELECTING COLUMNS FROM A DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# Return a column from the DataFrame
# Note that the output will be a Pandas Series (you can automatically tell by the lack of formating)
sample = employee_df['Email']
sample
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Confirm the datatype of sample
type(sample)
# Out:
# pandas.core.series.Series

# %%
# use the following syntax to do the same
# Note that this method will not work if there are spaces in the column names
employee_df.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Since the column name has spaces, this will be the only way that will work!
employee_df['Years with Company']
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %%
# Let's select multiple columns from the DataFrame
# define a list containing all column names that you would like to select
# Note that since collected more than one column, the output is a DataFrame (Notice the rich formatting)
sample = employee_df[['First Name', 'Salary']]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# Note that sample is now a DataFrame and not a Pandas Series (since it has multiple columns)
# use type to confirm or you can tell from the rich text formating
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
# Alternatively, define a list first and then use it to select columns
my_selected_columns = ['First Name', 'Salary']
sample = employee_df[my_selected_columns]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# In order to access a given row in the dataframe
employee_df[0:2]
# Out:
#   First Name Last Name  ...  Postal Code               Email
# 0       Mike       Moe  ...      N94 3M0      bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K  nsmall@hotmail.com
#
# [2 rows x 6 columns]

# %% [markdown]
# #ADDING/DELETING COLUMNS TO DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# assume that we want to add a new column to the dataframe
employee_df['Age'] = [25, 26, 28, 30, 36, 22, 48, 55, 70, 69]

# %%
employee_df
# Out:
#   First Name Last Name     Salary  ...  Postal Code                    Email Age
# 0       Mike       Moe    5000.00  ...      N94 3M0           bird@gmail.com  25
# 1       Noah      Ryan   10000.00  ...      N8S 14K       nsmall@hotmail.com  26
# 2       Nina    Keller    9072.02  ...      S1T 4E6          azikez@gahew.mr  28
# 3    Chanel      Steve   11072.02  ...      N7T 3E6         chanel@gmail.com  30
# 4       Kate      Noor    5000.00  ...      K8N 5H6         kate@hotmail.com  36
# 5      Samer        Mo  100000.00  ...      J7H 3HY          samer@gmail.com  22
# 6       Heba    Ismail   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com  48
# 7      Laila       Aly   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com  55
# 8     Joseph    Patton    2629.13  ...      M6U 5U7           daafeja@boh.jm  70
# 9       Noah     Moran    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw  69
#
# [10 rows x 7 columns]

# %%
# insert a new column in a given position 
employee_df.insert(0, column = 'Credit Score', value = [680, 700, 750, 699, 550, 600, 750, 500, 520, 510])

# %%
employee_df
# Out:
#    Credit Score First Name Last Name  ...  Postal Code                    Email Age
# 0           680       Mike       Moe  ...      N94 3M0           bird@gmail.com  25
# 1           700       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com  26
# 2           750       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr  28
# 3           699    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com  30
# 4           550       Kate      Noor  ...      K8N 5H6         kate@hotmail.com  36
# 5           600      Samer        Mo  ...      J7H 3HY          samer@gmail.com  22
# 6           750       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com  48
# 7           500      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com  55
# 8           520     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm  70
# 9           510       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw  69
#
# [10 rows x 8 columns]

# %%
# Delete a column from a DataFrame
del employee_df['Email']
employee_df
# Out:
#    Credit Score First Name Last Name  ...  Years with Company  Postal Code Age
# 0           680       Mike       Moe  ...                   3      N94 3M0  25
# 1           700       Noah      Ryan  ...                   8      N8S 14K  26
# 2           750       Nina    Keller  ...                  17      S1T 4E6  28
# 3           699    Chanel      Steve  ...                  12      N7T 3E6  30
# 4           550       Kate      Noor  ...                  23      K8N 5H6  36
# 5           600      Samer        Mo  ...                  13      J7H 3HY  22
# 6           750       Heba    Ismail  ...                   7      K8Y 3M8  48
# 7           500      Laila       Aly  ...                   5      J8Y 3M0  55
# 8           520     Joseph    Patton  ...                   2      M6U 5U7  70
# 9           510       Noah     Moran  ...                  11      K2D 4M9  69
#
# [10 rows x 7 columns]

# %%
employee_df.drop(labels = ["Last Name", "Salary"], axis = 1, inplace = True)
employee_df
# Out:
#    Credit Score First Name  Years with Company Postal Code  Age
# 0           680       Mike                   3     N94 3M0   25
# 1           700       Noah                   8     N8S 14K   26
# 2           750       Nina                  17     S1T 4E6   28
# 3           699    Chanel                   12     N7T 3E6   30
# 4           550       Kate                  23     K8N 5H6   36
# 5           600      Samer                  13     J7H 3HY   22
# 6           750       Heba                   7     K8Y 3M8   48
# 7           500      Laila                   5     J8Y 3M0   55
# 8           520     Joseph                   2     M6U 5U7   70
# 9           510       Noah                  11     K2D 4M9   69

# %%
# Remove a column from a DataFrame and store it somehwere else using pop
Years_with_company = employee_df.pop("Years with Company")
Years_with_company
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %% [markdown]
# #LABEL-BASED ELEMENTS SELECTION FROM A DATAFRAME ".LOC()"

# %%
# Load the csv file and set the last name as the index
employee_df = pd.read_csv('employee_information.csv', index_col = 'Last Name')
employee_df
# Out:
#           First Name     Salary  ...  Postal Code                    Email
# Last Name                        ...
# Moe             Mike    5000.00  ...      N94 3M0           bird@gmail.com
# Ryan            Noah   10000.00  ...      N8S 14K       nsmall@hotmail.com
# Keller          Nina    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Steve        Chanel    11072.02  ...      N7T 3E6         chanel@gmail.com
# Noor            Kate    5000.00  ...      K8N 5H6         kate@hotmail.com
# Mo             Samer  100000.00  ...      J7H 3HY          samer@gmail.com
# Ismail          Heba   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Aly            Laila   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Patton        Joseph    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Moran           Noah    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 5 columns]

# %%
# Sort the dataframe in an alphabetical order
employee_df.sort_index(inplace = True)

# %%
employee_df
# Out:
#           First Name     Salary  ...  Postal Code                    Email
# Last Name                        ...
# Aly            Laila   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Ismail          Heba   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Keller          Nina    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Mo             Samer  100000.00  ...      J7H 3HY          samer@gmail.com
# Moe             Mike    5000.00  ...      N94 3M0           bird@gmail.com
# Moran           Noah    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
# Noor            Kate    5000.00  ...      K8N 5H6         kate@hotmail.com
# Patton        Joseph    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Ryan            Noah   10000.00  ...      N8S 14K       nsmall@hotmail.com
# Steve        Chanel    11072.02  ...      N7T 3E6         chanel@gmail.com
#
# [10 rows x 5 columns]

# %%
# loc is used to filter rows and columns
# loc is label-based meaning need to give a name of the rows (or columns)
# Note that iloc is "integer index-based" meaning filter rows/columns by their integer index.

employee_df.loc['Aly']
# Out:
# First Name                          Laila
# Salary                              20000
# Years with Company                      5
# Postal Code                       J8Y 3M0
# Email                 Laila.a@hotmail.com
# Name: Aly, dtype: object

# %%
# select multiple rows using "colon :"
# Note that this is inclusive! meaning that "Aly" and "Patton" were selected in the output DataFrame
# Headsup: this will be different if we use integer based index such as iloc()

employee_df.loc['Aly':'Patton']
# Out:
#           First Name     Salary  ...  Postal Code                    Email
# Last Name                        ...
# Aly            Laila   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Ismail          Heba   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Keller          Nina    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Mo             Samer  100000.00  ...      J7H 3HY          samer@gmail.com
# Moe             Mike    5000.00  ...      N94 3M0           bird@gmail.com
# Moran           Noah    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
# Noor            Kate    5000.00  ...      K8N 5H6         kate@hotmail.com
# Patton        Joseph    2629.13  ...      M6U 5U7           daafeja@boh.jm
#
# [8 rows x 5 columns]

# %%
# Select all elements up to and including 'Keller' index
employee_df.loc[:'Keller']
# Out:
#           First Name    Salary  ...  Postal Code                    Email
# Last Name                       ...
# Aly            Laila  20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Ismail          Heba  50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Keller          Nina   9072.02  ...      S1T 4E6          azikez@gahew.mr
#
# [3 rows x 5 columns]

# %%
# select multiple rows, you can pass them as a list as follows
employee_df.loc[["Keller", "Steve", "Mo"]]
# Out:
#           First Name     Salary  ...  Postal Code             Email
# Last Name                        ...
# Keller          Nina    9072.02  ...      S1T 4E6   azikez@gahew.mr
# Steve        Chanel    11072.02  ...      N7T 3E6  chanel@gmail.com
# Mo             Samer  100000.00  ...      J7H 3HY   samer@gmail.com
#
# [3 rows x 5 columns]

# %%
# randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns
employee_df.sample(n = 5, axis = 0)
# Out:
#           First Name     Salary  ...  Postal Code                    Email
# Last Name                        ...
# Patton        Joseph    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Mo             Samer  100000.00  ...      J7H 3HY          samer@gmail.com
# Ismail          Heba   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Moran           Noah    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
# Aly            Laila   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
#
# [5 rows x 5 columns]

# %%
# return a percentage (Ex: 30%) of the rows 
employee_df.sample(frac = 0.3, axis = 0)
# Out:
#           First Name    Salary  ...  Postal Code               Email
# Last Name                       ...
# Keller          Nina   9072.02  ...      S1T 4E6     azikez@gahew.mr
# Ryan            Noah  10000.00  ...      N8S 14K  nsmall@hotmail.com
# Patton        Joseph   2629.13  ...      M6U 5U7      daafeja@boh.jm
#
# [3 rows x 5 columns]

# %% [markdown]
# #INTEGER INDEX-BASED ELEMENTS SELECTION FROM A DATAFRAME "iLOC()"

# %%
# Load the CSV file with default index
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# access rows with their numeric index using iloc
employee_df.iloc[9]
# Out:
# First Name                         Noah
# Last Name                         Moran
# Salary                          8626.96
# Years with Company                   11
# Postal Code                     K2D 4M9
# Email                 guutodi@bigwoc.kw
# Name: 9, dtype: object

# %%
# access multiple rows with their numeric index using iloc and colon :
# Note that using iloc is exclusive
# from index = 2 up until and not including index 5 so index 2,3, and 4 are the one selected
employee_df.iloc[2:5]
# Out:
#   First Name Last Name  ...  Postal Code             Email
# 2       Nina    Keller  ...      S1T 4E6   azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6  chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6  kate@hotmail.com
#
# [3 rows x 6 columns]

# %%
# all up until and not including index 4
employee_df.iloc[:4]
# Out:
#   First Name Last Name  ...  Postal Code               Email
# 0       Mike       Moe  ...      N94 3M0      bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K  nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6     azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6    chanel@gmail.com
#
# [4 rows x 6 columns]

# %%
# Multiple elements are selected using a list of indexes 
employee_df.iloc[[2, 4, 9]]
# Out:
#   First Name Last Name  ...  Postal Code              Email
# 2       Nina    Keller  ...      S1T 4E6    azikez@gahew.mr
# 4       Kate      Noor  ...      K8N 5H6   kate@hotmail.com
# 9       Noah     Moran  ...      K2D 4M9  guutodi@bigwoc.kw
#
# [3 rows x 6 columns]

# %%
# Slicing a piece of the dataframe by selecting which row and column you would like to select
employee_df.iloc[4, 0:3]
# Out:
# First Name    Kate
# Last Name     Noor
# Salary        5000
# Name: 4, dtype: object

# %% [markdown]
# #BROADCASTING OPERATIONS & SETTING NEW DATAFRAME VALUES

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# Let's assume that we want to update the salaries of all our employees by $1000
employee_df['Salary'] = employee_df['Salary'] + 1000

# %%
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# Alternatively, add or subtract as follows
employee_df['Salary'] = employee_df['Salary'].add(1000)
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 
employee_df['Salary (CAD)'] = employee_df['Salary'].mul(1.3)
employee_df
# Out:
#   First Name Last Name  ...                    Email  Salary (CAD)
# 0       Mike       Moe  ...           bird@gmail.com      9100.000
# 1       Noah      Ryan  ...       nsmall@hotmail.com     15600.000
# 2       Nina    Keller  ...          azikez@gahew.mr     14393.626
# 3    Chanel      Steve  ...         chanel@gmail.com     16993.626
# 4       Kate      Noor  ...         kate@hotmail.com      9100.000
# 5      Samer        Mo  ...          samer@gmail.com    132600.000
# 6       Heba    Ismail  ...  heba.ismail@hotmail.com     67600.000
# 7      Laila       Aly  ...      Laila.a@hotmail.com     28600.000
# 8     Joseph    Patton  ...           daafeja@boh.jm      6017.869
# 9       Noah     Moran  ...        guutodi@bigwoc.kw     13815.048
#
# [10 rows x 7 columns]

# %%
# Decided to update the email address of a given customer
employee_df.iloc[4, 5] = 'kate.noor@gmail.com'

# %%
employee_df
# Out:
#   First Name Last Name  ...                    Email  Salary (CAD)
# 0       Mike       Moe  ...           bird@gmail.com      9100.000
# 1       Noah      Ryan  ...       nsmall@hotmail.com     15600.000
# 2       Nina    Keller  ...          azikez@gahew.mr     14393.626
# 3    Chanel      Steve  ...         chanel@gmail.com     16993.626
# 4       Kate      Noor  ...      kate.noor@gmail.com      9100.000
# 5      Samer        Mo  ...          samer@gmail.com    132600.000
# 6       Heba    Ismail  ...  heba.ismail@hotmail.com     67600.000
# 7      Laila       Aly  ...      Laila.a@hotmail.com     28600.000
# 8     Joseph    Patton  ...           daafeja@boh.jm      6017.869
# 9       Noah     Moran  ...        guutodi@bigwoc.kw     13815.048
#
# [10 rows x 7 columns]

# %% [markdown]
# #SORTING AND ORDERING

# %%
# read a CSV file using Pandas as follows
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# sort the values in the dataframe according to number of years with bank
employee_df.sort_values(by = 'Years with Company')
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
#
# [10 rows x 6 columns]

# %%
employee_df.sort_values(by = 'Years with Company', inplace = True)

# %%
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
#
# [10 rows x 6 columns]

# %%
employee_df.sort_values(by = 'Years with Company', ascending = False, inplace = True) 
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
#
# [10 rows x 6 columns]

# %%
employee_df.sort_index(inplace = True) 
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **A porfolio contains a collection of securities such as stocks, bonds and ETFs. Define a dataframe named 'portfolio_df' that holds 3 different stock ticker symbols, number of shares, and price per share (feel free to choose any stocks)**
# - **Calculate the total value of the porfolio including all stocks**

# %%
portfolio_df = pd.DataFrame({'stock ticker symbols':['FB', 'TSLA', 'T'],
                             'price per share [$]':[3800, 300, 400], 
                             'Number of stocks':[4, 7, 10]})
portfolio_df
# Out:
#   stock ticker symbols  price per share [$]  Number of stocks
# 0                   FB                 3800                 4
# 1                 TSLA                  300                 7
# 2                    T                  400                10

# %%
stocks_dollar_value = portfolio_df['price per share [$]'] * portfolio_df['Number of stocks']
print(stocks_dollar_value)
# Out:
# 0    15200
# 1     2100
# 2     4000
# dtype: int64

# %%
print('Total portfolio value = {}'.format(stocks_dollar_value.sum()))
# Out:
# Total portfolio value = 21300

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Write a code that uses Pandas to read tabular US retirement data**
# - **You can use data from here: https://www.ssa.gov/oact/progdata/nra.html**

# %%
# Read tabular data using read_html
retirement_age_df = pd.read_html('https://www.ssa.gov/oact/progdata/nra.html')
retirement_age_df
# Out:
# [                                        Year of birth                                                Age
#  0                                      1937 and prior                                                 65
#  1                                                1938                                    65 and 2 months
#  2                                                1939                                    65 and 4 months
#  3                                                1940                                    65 and 6 months
#  4                                                1941                                    65 and 8 months
#  5                                                1942                                   65 and 10 months
#  6                                             1943-54                                                 66
#  7                                                1955                                    66 and 2 months
#  8                                                1956                                    66 and 4 months
#  9                                                1957                                    66 and 6 months
#  10                                               1958                                    66 and 8 months
#  11                                               1959                                   66 and 10 months
#  12                                     1960 and later                                                 67
#  13  Notes: 1. Persons born on January 1 of any yea...  Notes: 1. Persons born on January 1 of any yea...]

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Use set index = False and rerun the cell. Comment on the output CSV.**

# %%
# write to a csv file without an index
employee_df.to_csv('employee_info_noindex.csv', index = False)

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Load the employee_information.csv and then set the "Last Name" column as the index**

# %%
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# assign a specific column to be the index as follows
employee_df.set_index("Last Name", inplace = True)
employee_df
# Out:
#           First Name     Salary  ...  Postal Code                    Email
# Last Name                        ...
# Moe             Mike    5000.00  ...      N94 3M0           bird@gmail.com
# Ryan            Noah   10000.00  ...      N8S 14K       nsmall@hotmail.com
# Keller          Nina    9072.02  ...      S1T 4E6          azikez@gahew.mr
# Steve        Chanel    11072.02  ...      N7T 3E6         chanel@gmail.com
# Noor            Kate    5000.00  ...      K8N 5H6         kate@hotmail.com
# Mo             Samer  100000.00  ...      J7H 3HY          samer@gmail.com
# Ismail          Heba   50000.00  ...      K8Y 3M8  heba.ismail@hotmail.com
# Aly            Laila   20000.00  ...      J8Y 3M0      Laila.a@hotmail.com
# Patton        Joseph    2629.13  ...      M6U 5U7           daafeja@boh.jm
# Moran           Noah    8626.96  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 5 columns]

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Select the following columns from the dataFrame Salary, Years with Company, and Postal Code**

# %%
my_selected_columns = ['Salary', 'Years with Company', 'Postal Code']
sample = employee_df[my_selected_columns]
sample
# Out:
#               Salary  Years with Company Postal Code
# Last Name
# Moe          5000.00                   3     N94 3M0
# Ryan        10000.00                   8     N8S 14K
# Keller       9072.02                  17     S1T 4E6
# Steve       11072.02                  12     N7T 3E6
# Noor         5000.00                  23     K8N 5H6
# Mo         100000.00                  13     J7H 3HY
# Ismail      50000.00                   7     K8Y 3M8
# Aly         20000.00                   5     J8Y 3M0
# Patton       2629.13                   2     M6U 5U7
# Moran        8626.96                  11     K2D 4M9

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **load the employee_information.csv file and perform the following: (assume any reasonable values)**
#     - **Add a column indicating whether the employee has a mortgage or not**
#     - **Add a column indicating the value of mortage in dollars**

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df

employee_df['Has Mortage'] = [1, 1, 0, 0, 0, 0, 1, 0, 0, 0]
employee_df['Mortage Value'] = [200000, 130000, 0, 0, 0, 0, 400000, 0, 0, 0]
employee_df
# Out:
#   First Name Last Name  ...  Has Mortage  Mortage Value
# 0       Mike       Moe  ...            1         200000
# 1       Noah      Ryan  ...            1         130000
# 2       Nina    Keller  ...            0              0
# 3    Chanel      Steve  ...            0              0
# 4       Kate      Noor  ...            0              0
# 5      Samer        Mo  ...            0              0
# 6       Heba    Ismail  ...            1         400000
# 7      Laila       Aly  ...            0              0
# 8     Joseph    Patton  ...            0              0
# 9       Noah     Moran  ...            0              0
#
# [10 rows x 8 columns]

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Load the csv data and use the "first name" column as the index**
# - **Randomly select 2 rows from the DataFrame. Rerun the code and ensure that random rows are being selected**

# %%
# Load the csv file and set the last name as the index
employee_df = pd.read_csv('employee_information.csv', index_col = 'First Name')
employee_df

# Setting axis = 0 means rows, setting index = 1 means columns
employee_df.sample(n = 2, axis = 0)
# Out:
#            Last Name   Salary  Years with Company Postal Code            Email
# First Name
# Nina          Keller  9072.02                  17     S1T 4E6  azikez@gahew.mr
# Mike             Moe  5000.00                   3     N94 3M0   bird@gmail.com

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Write a code that selects the last two rows in the DataFrame using two different methods**

# %%
employee_df.iloc[8:]
# Out:
#            Last Name   Salary  ...  Postal Code              Email
# First Name                     ...
# Joseph        Patton  2629.13  ...      M6U 5U7     daafeja@boh.jm
# Noah           Moran  8626.96  ...      K2D 4M9  guutodi@bigwoc.kw
#
# [2 rows x 5 columns]

# %%
employee_df.iloc[-2:]
# Out:
#            Last Name   Salary  ...  Postal Code              Email
# First Name                     ...
# Joseph        Patton  2629.13  ...      M6U 5U7     daafeja@boh.jm
# Noah           Moran  8626.96  ...      K2D 4M9  guutodi@bigwoc.kw
#
# [2 rows x 5 columns]

# %% [markdown]
# **MINI CHALLENGE #9:**
# - **Let's assume that all employees have been performing really well and their salaries have increased by 12% annualy. Calculate the sum of all employees salaries.**

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name  ...  Postal Code                    Email
# 0       Mike       Moe  ...      N94 3M0           bird@gmail.com
# 1       Noah      Ryan  ...      N8S 14K       nsmall@hotmail.com
# 2       Nina    Keller  ...      S1T 4E6          azikez@gahew.mr
# 3    Chanel      Steve  ...      N7T 3E6         chanel@gmail.com
# 4       Kate      Noor  ...      K8N 5H6         kate@hotmail.com
# 5      Samer        Mo  ...      J7H 3HY          samer@gmail.com
# 6       Heba    Ismail  ...      K8Y 3M8  heba.ismail@hotmail.com
# 7      Laila       Aly  ...      J8Y 3M0      Laila.a@hotmail.com
# 8     Joseph    Patton  ...      M6U 5U7           daafeja@boh.jm
# 9       Noah     Moran  ...      K2D 4M9        guutodi@bigwoc.kw
#
# [10 rows x 6 columns]

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 
employee_df['Salary New'] = employee_df['Salary'].mul(1.12)
employee_df
# Out:
#   First Name Last Name  ...                    Email   Salary New
# 0       Mike       Moe  ...           bird@gmail.com    5600.0000
# 1       Noah      Ryan  ...       nsmall@hotmail.com   11200.0000
# 2       Nina    Keller  ...          azikez@gahew.mr   10160.6624
# 3    Chanel      Steve  ...         chanel@gmail.com   12400.6624
# 4       Kate      Noor  ...         kate@hotmail.com    5600.0000
# 5      Samer        Mo  ...          samer@gmail.com  112000.0000
# 6       Heba    Ismail  ...  heba.ismail@hotmail.com   56000.0000
# 7      Laila       Aly  ...      Laila.a@hotmail.com   22400.0000
# 8     Joseph    Patton  ...           daafeja@boh.jm    2944.6256
# 9       Noah     Moran  ...        guutodi@bigwoc.kw    9662.1952
#
# [10 rows x 7 columns]

# %%
employee_df['Salary New'].sum()
# Out:
# 247968.14560000002

# %%
print("Total networth for all clients = ${}".format( employee_df['Salary New'].sum()))
# Out:
# Total networth for all clients = $247968.14560000002

# %% [markdown]
# **MINI CHALLENGE #10:**
# - **Sort employees by salaries instead of years with Company. Make sure to update values in-memory.**

# %%
# sort the values in the dataframe according to number of years with bank
employee_df.sort_values(by = 'Salary', inplace = True) 
employee_df
# Out:
#   First Name Last Name  ...                    Email   Salary New
# 8     Joseph    Patton  ...           daafeja@boh.jm    2944.6256
# 0       Mike       Moe  ...           bird@gmail.com    5600.0000
# 4       Kate      Noor  ...         kate@hotmail.com    5600.0000
# 9       Noah     Moran  ...        guutodi@bigwoc.kw    9662.1952
# 2       Nina    Keller  ...          azikez@gahew.mr   10160.6624
# 1       Noah      Ryan  ...       nsmall@hotmail.com   11200.0000
# 3    Chanel      Steve  ...         chanel@gmail.com   12400.6624
# 7      Laila       Aly  ...      Laila.a@hotmail.com   22400.0000
# 6       Heba    Ismail  ...  heba.ismail@hotmail.com   56000.0000
# 5      Samer        Mo  ...          samer@gmail.com  112000.0000
#
# [10 rows x 7 columns]
